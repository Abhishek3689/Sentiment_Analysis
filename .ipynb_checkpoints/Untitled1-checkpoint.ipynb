# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
df=pd.read_csv("Customer_feedback.csv",encoding='latin-1')

# %%
df.head()
# Out:
#    Number                                  responses_message binary_score
# 0       0  I took a loan of 100,000 rubles in 2015. The o...     negative
# 1       1  For a little more than a year I issued your ca...     positive
# 2       2  I would like to ask a question. By what right ...     negative
# 3       3  When applying for a consumer loan in the CC at...     negative
# 4       4  08/10/17 my husband received an SMS about the ...     negative

# %%
df.isnull().sum()
# Out:
# Number               0
# responses_message    0
# binary_score         8
# dtype: int64

# %%
df.shape
# Out:
# (16659, 3)

# %%
df.dtypes
# Out:
# Number                int64
# responses_message    object
# binary_score         object
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (16651, 3)

# %%
df_review=df.copy()

# %%
df_review['binary_score'].value_counts()
# Out:
# negative    10906
# positive     5745
# Name: binary_score, dtype: int64

# %%
df_review['binary_score'].value_counts(normalize=True)*100
# Out:
# negative    65.497568
# positive    34.502432
# Name: binary_score, dtype: float64

# %%
df_review['binary_score']=df_review['binary_score'].map({'negative':0,'positive':1})

# %%
df_review.head()
# Out:
#    Number                                  responses_message  binary_score
# 0       0  I took a loan of 100,000 rubles in 2015. The o...             0
# 1       1  For a little more than a year I issued your ca...             1
# 2       2  I would like to ask a question. By what right ...             0
# 3       3  When applying for a consumer loan in the CC at...             0
# 4       4  08/10/17 my husband received an SMS about the ...             0

# %%
import nltk

# %%
sns.countplot(data=df_review,x=df_review['binary_score'])
# Out:
# <Axes: xlabel='binary_score', ylabel='count'>

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping misc\perluniprops.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\sanga\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
df_review['responses_message'][4]
# Out:
# '08/10/17 my husband received an SMS about the approved proposal for 500,000 rubles.\xa0Just needed money, we decided to apply.\xa0We went to the nearest office at ul.\xa0Vvedensky, d. 13A.\xa0They submitted an application, within half an hour they approved a loan of 500,000. They began to apply for and then suddenly a bank employee reported that an error had occurred and she had issued a loan of 704,000 rubles, and supposedly this money had already been transferred to her husband\x92s account.\xa0In fact, the amount of 489,000 rubles was on the card.\xa0In this case, the contract and payment are considered based on the amount of 704,000 rubles.\xa0The employee was not able to cope with the situation herself, 2 more ran up to her aid, her husband began to receive SMS codes with codes on the phone, the girls asked to give them these codes, explaining this by the fact that they are trying to correct the situation and they need to enter some kind of security code.\xa0And so they sent 4 codes that were given to them (later they found out that they had thus written off three times each 3,000 rubles and once 2,000 rubles from the husband\x92s card) When the bank employee was asked questions, what\x92s the matter, where the rest of the money, she claimed that an error had occurred and 180,000 went to insurance (it was not clear which she could not explain).\xa0As a result, they sent us to the client center.\xa0We went to another office on Vavilova d. 6. They explained that 180,000 is life insurance for the duration of the loan, 2,000 is the tree that we allegedly planted and 9,000 are some other box products, including a credit request stories.\xa0In this department, we at least have printed these products.\xa0We were shocked by this.\xa0It turns out that we were brazenly deceived, not having voiced all this information.\xa0Pure fraud.\xa0After long trials for several days, we were told that you can write a waiver of insurance and supposedly within 10 days the money will come to our account, but again not all, 2,000 rubles will not be returned, for a tree, it is not clear which and where we planted .\xa0They wanted to urgently refuse such a loan, but the employees said that it was impossible.\xa0We are sitting waiting for the outcome of 10 days.\xa0I think that this is the most natural fraud, intentional misrepresentation.\xa0We will never contact this bank again and do not advise anyone.\xa0We lost a lot of nerves and time, in the arms with a baby we had to understand this whole situation.\xa0I hope for a favorable outcome, otherwise I will have to go to court and the central bank.\xa0Be careful.'

# %%
from nltk.corpus import stopwords

# %%
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
import re

# %%
stemmer=PorterStemmer()

# %%
lemmatizer=WordNetLemmatizer()

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
sample=df_review['responses_message'][0]

# %%
sentence_sample=sent_tokenize(sample)

# %%
len(sentence_sample)
# Out:
# 10

# %%
word_sample=word_tokenize(sample)

# %%
type(word_sample)
# Out:
# list

# %%
re.sub('[^a-zA-Z]',' ',word_sample)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 re.sub('[^a-zA-Z]',' ',word_sample)
#
# File ~\anaconda3\lib\re.py:210, in sub(pattern, repl, string, count, flags)
#     203 def sub(pattern, repl, string, count=0, flags=0):
#     204     """Return the string obtained by replacing the leftmost
#     205     non-overlapping occurrences of the pattern in string by the
#     206     replacement repl.  repl can be either a string or a callable;
#     207     if a string, backslash escapes in it are processed.  If it is
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object

# %%
sub_words=re.sub('[^a-zA-Z]',' ',sample)

# %%
lower_sub=sub_words.lower()

# %%
lower_sub.split()
# Out:
# ['i',
#  'took',
#  'a',
#  'loan',
#  'of',
#  'rubles',
#  'in',
#  'the',
#  'office',
#  'immediately',
#  'began',
#  'to',
#  'breed',
#  'for',
#  'additional',
#  'services',
#  'insurance',
#  'etc',
#  'under',
#  'the',
#  'terms',
#  'they',
#  'lied',
#  'absolutely',
#  'everything',
#  'when',
#  'i',
#  'was',
#  'about',
#  'to',
#  'leave',
#  'the',
#  'conditions',
#  'softened',
#  'as',
#  'a',
#  'result',
#  'after',
#  'a',
#  'year',
#  'of',
#  'payments',
#  'on',
#  'schedule',
#  'i',
#  'owed',
#  'rubles',
#  'another',
#  'year',
#  'passed',
#  'and',
#  'i',
#  'boldly',
#  'assumed',
#  'that',
#  'the',
#  'balance',
#  'was',
#  'not',
#  'more',
#  'than',
#  'on',
#  'the',
#  'loan',
#  'as',
#  'i',
#  'literally',
#  'put',
#  'it',
#  'i',
#  'was',
#  'surprised',
#  'when',
#  'after',
#  'another',
#  'year',
#  'i',
#  'owed',
#  'less',
#  'on',
#  'the',
#  'main',
#  'debt',
#  'of',
#  'only',
#  'rubles',
#  'less',
#  'totaling',
#  'rubles',
#  'that',
#  'is',
#  'for',
#  'months',
#  'of',
#  'payments',
#  'in',
#  'the',
#  'amount',
#  'of',
#  'at',
#  'least',
#  'rubles',
#  'less',
#  'than',
#  'rubles',
#  'were',
#  'written',
#  'off',
#  'from',
#  'the',
#  'main',
#  'debt',
#  'i',
#  'have',
#  'not',
#  'seen',
#  'such',
#  'predatory',
#  'movements',
#  'in',
#  'any',
#  'bank',
#  'in',
#  'no',
#  'case',
#  'do',
#  'not',
#  'contact',
#  'them']

# %%
for word in lower_sub:
    print(word)
# Out:
# i
#
# t
# o
# o
# k
#
# a
#
# l
# o
# a
# n
#
# o
# f
#
#
#
#
#
#
#
#
#
# r
# u
# b
# l
# e
# s
#
# i
# n
#
#
#
#
#
#
#
# t
# h
# e
#
# o
# f
# f
# i
# c
# e
#
# i
# m
# m
# e
# d
# i
# a
# t
# e
# l
# y
#
# b
# e
# g
# a
# n
#
# t
# o
#
# b
# r
# e
# e
# d
#
# f
# o
# r
#
# a
# d
# d
# i
# t
# i
# o
# n
# a
# l
#
# s
# e
# r
# v
# i
# c
# e
# s
#
#
# i
# n
# s
# u
# r
# a
# n
# c
# e
#
#
# e
# t
# c
#
#
# u
# n
# d
# e
# r
#
# t
# h
# e
#
# t
# e
# r
# m
# s
#
#
# t
# h
# e
# y
#
# l
# i
# e
# d
#
# a
# b
# s
# o
# l
# u
# t
# e
# l
# y
#
# e
# v
# e
# r
# y
# t
# h
# i
# n
# g
#
#
# w
# h
# e
# n
#
# i
#
# w
# a
# s
#
# a
# b
# o
# u
# t
#
# t
# o
#
# l
# e
# a
# v
# e
#
#
# t
# h
# e
#
# c
# o
# n
# d
# i
# t
# i
# o
# n
# s
#
# s
# o
# f
# t
# e
# n
# e
# d
#
#
# a
# s
#
# a
#
# r
# e
# s
# u
# l
# t
#
#
# a
# f
# t
# e
# r
#
# a
#
# y
# e
# a
# r
#
# o
# f
#
# p
# a
# y
# m
# e
# n
# t
# s
#
# o
# n
#
# s
# c
# h
# e
# d
# u
# l
# e
#
#
# i
#
# o
# w
# e
# d
#
#
#
#
#
#
#
#
# r
# u
# b
# l
# e
# s
#
#
# a
# n
# o
# t
# h
# e
# r
#
# y
# e
# a
# r
#
# p
# a
# s
# s
# e
# d
#
# a
# n
# d
#
# i
#
# b
# o
# l
# d
# l
# y
#
# a
# s
# s
# u
# m
# e
# d
#
# t
# h
# a
# t
#
# t
# h
# e
#
# b
# a
# l
# a
# n
# c
# e
#
# w
# a
# s
#
# n
# o
# t
#
# m
# o
# r
# e
#
# t
# h
# a
# n
#
#
#
#
#
#
#
#
# o
# n
#
# t
# h
# e
#
# l
# o
# a
# n
#
#
# a
# s
#
# i
#
# l
# i
# t
# e
# r
# a
# l
# l
# y
#
# p
# u
# t
#
# i
# t
#
#
# i
#
# w
# a
# s
#
# s
# u
# r
# p
# r
# i
# s
# e
# d
#
# w
# h
# e
# n
#
#
# a
# f
# t
# e
# r
#
# a
# n
# o
# t
# h
# e
# r
#
# y
# e
# a
# r
#
#
# i
#
# o
# w
# e
# d
#
# l
# e
# s
# s
#
# o
# n
#
# t
# h
# e
#
# m
# a
# i
# n
#
# d
# e
# b
# t
#
# o
# f
#
# o
# n
# l
# y
#
#
#
#
#
#
#
# r
# u
# b
# l
# e
# s
#
# l
# e
# s
# s
#
#
# t
# o
# t
# a
# l
# i
# n
# g
#
#
#
#
#
#
#
#
# r
# u
# b
# l
# e
# s
#
#
# t
# h
# a
# t
#
# i
# s
#
#
# f
# o
# r
#
#
#
#
# m
# o
# n
# t
# h
# s
#
# o
# f
#
# p
# a
# y
# m
# e
# n
# t
# s
#
# i
# n
#
# t
# h
# e
#
# a
# m
# o
# u
# n
# t
#
# o
# f
#
# a
# t
#
# l
# e
# a
# s
# t
#
#
#
#
#
#
#
#
# r
# u
# b
# l
# e
# s
#
#
# l
# e
# s
# s
#
# t
# h
# a
# n
#
#
#
#
#
#
#
# r
# u
# b
# l
# e
# s
#
# w
# e
# r
# e
#
# w
# r
# i
# t
# t
# e
# n
#
# o
# f
# f
#
# f
# r
# o
# m
#
# t
# h
# e
#
# m
# a
# i
# n
#
# d
# e
# b
# t
#
#
# i
#
# h
# a
# v
# e
#
# n
# o
# t
#
# s
# e
# e
# n
#
# s
# u
# c
# h
#
# p
# r
# e
# d
# a
# t
# o
# r
# y
#
# m
# o
# v
# e
# m
# e
# n
# t
# s
#
# i
# n
#
# a
# n
# y
#
# b
# a
# n
# k
#
#
# i
# n
#
# n
# o
#
# c
# a
# s
# e
#
# d
# o
#
# n
# o
# t
#
# c
# o
# n
# t
# a
# c
# t
#
# t
# h
# e
# m

# %%
## this function will take string data and convert into cleaned string
def clean_data_with_stopwords(df):
    text=re.sub('[^a-zA-Z]',' ',df)
    text=text.lower()
    text=text.split()
    lemmatize_txt=[lemmatizer.lemmatize(word) for word in text if word not in set(stopwords.words('english'))]
    final_word=' '.join(lemmatize_txt)
    return final_word

# %%
s1=clean_data_with_stopwords(sample)

# %%
s1
# Out:
# 'took loan ruble office immediately began breed additional service insurance etc term lied absolutely everything leave condition softened result year payment schedule owed ruble another year passed boldly assumed balance loan literally put surprised another year owed le main debt ruble le totaling ruble month payment amount least ruble le ruble written main debt seen predatory movement bank case contact'

# %%
len(s1)
# Out:
# 405

# %%
len(sample)
# Out:
# 757

# %%
df_review_50=df_review[:50]

# %%
# %%time
df_review_50['responses_message'].apply(clean_data_with_stopwords)
# Out:
# CPU times: total: 8.98 s
# Wall time: 9.94 s
# 0     took loan ruble office immediately began breed...
# 1     little year issued card interest free period m...
# 2     would like ask question right bank name third ...
# 3     applying consumer loan cc ul mitinskaya amount...
# 4     husband received sm approved proposal ruble ne...
# 5     eager get element credit card naively deciding...
# 6     signed loan agreement describe employee k kov ...
# 7     august completed full early repayment loan con...
# 8     good afternoon difficult convey indignation wo...
# 9     long time bank employee called friend loan wit...
# 10    recently use service post bank impression plea...
# 11    tonight hacked mail bk ru mailing contact addr...
# 12    un luck take consumer loan bank one payment ex...
# 13    received sm pjsc post bank previously summer b...
# 14    claim borrower loan agreement according paymen...
# 15    good afternoon know august hot time vacation o...
# 16    good afternoon want share impression post bank...
# 17    long bank terrorize call parent live applying ...
# 18    used bank service several year would still let...
# 19    good afternoon really wanted leave positive re...
# 20    general situation wanted take child rub withou...
# 21    delayed payment card paid single delay employe...
# 22    took loan post bank stage signing contract tur...
# 23    end last month st turned post bank following a...
# 24    never client bank apparently never couple mont...
# 25    turned post bank accident necessary pay receip...
# 26    received email message generated automatically...
# 27    start criticism fact year last month issued cr...
# 28    day ago manager post bank called loan offer po...
# 29    good afternoon dear manager post bank today ph...
# 30    registered saving account post office grazhdan...
# 31    took loan year result loan body miraculously b...
# 32    end august tried get consumer loan post bank b...
# 33    want say thank daughter went first grade think...
# 34    hello bank customer twice first time problem e...
# 35    first last time used service postbank issued l...
# 36    would like leave review bank right time helped...
# 37    good afternoon want share experience cooperati...
# 38    consumer loan issued pjsc summer bank fulfill ...
# 39    recently became client bank opened saving acco...
# 40    worst bank ever met outspoken deceiver especia...
# 41    tell sad experience cooperation post bank time...
# 42    good day would like share opinion post bank lo...
# 43    good afternoon essence appeal wandered august ...
# 44    good afternoon approved application bank rate ...
# 45    dear representative postal bank please clarify...
# 46    purchased pyaterochka postal bank debit card a...
# 47    good afternoon yesterday sim card purchased mo...
# 48    want note good bank urgently needed money able...
# 49    good afternoon want complain branch pochtabank...
# Name: responses_message, dtype: object

# %%
## This functions will take df and column name so that it will return complete cospurs with celaned text
def clean_data_with_stopwords_df(df,column):
    corpus=[]
    for i in range(len(df)):
        text=re.sub('[^a-zA-Z]',' ',df[column][i])
        text=text.lower()
        text=text.split()
        lemmatize_txt=[lemmatizer.lemmatize(word) for word in text if word not in set(stopwords.words('english'))]
        final_word=' '.join(lemmatize_txt)
        corpus.append(final_word)
    return corpus

# %%
# %%time
cleaned_corpus=clean_data_with_stopwords(df_review,'responses_message')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[77], line 7, in clean_data_with_stopwords(df, column)
#       5 text=text.lower()
#       6 text=text.split()
# ----> 7 lemmatize_txt=[lemmatizer.lemmatize(word) for word in text if word not in set(stopwords.words('english'))]
#       8 final_word=' '.join(lemmatize_txt)
#       9 corpus.append(final_word)
#
# Cell In[77], line 7, in <listcomp>(.0)
#       5 text=text.lower()
#       6 text=text.split()
# ----> 7 lemmatize_txt=[lemmatizer.lemmatize(word) for word in text if word not in set(stopwords.words('english'))]
#       8 final_word=' '.join(lemmatize_txt)
#       9 corpus.append(final_word)
#
# File ~\anaconda3\lib\site-packages\nltk\corpus\reader\wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# File ~\anaconda3\lib\site-packages\nltk\corpus\reader\api.py:219, in CorpusReader.raw(self, fileids)
#     217 for f in fileids:
#     218     with self.open(f) as fp:
# --> 219         contents.append(fp.read())
#     220 return concat(contents)
#
# File ~\anaconda3\lib\site-packages\nltk\data.py:1167, in SeekableUnicodeStreamReader.__exit__(self, type, value, traceback)
#    1166 def __exit__(self, type, value, traceback):
# -> 1167     self.close()
#
# File ~\anaconda3\lib\site-packages\nltk\data.py:1196, in SeekableUnicodeStreamReader.close(self)
#    1192 def close(self):
#    1193     """
#    1194     Close the underlying stream.
#    1195     """
# -> 1196     self.stream.close()
#
# KeyboardInterrupt:
